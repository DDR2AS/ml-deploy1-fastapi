# %%
import requests

BASE = "https://ml-model1-service-675858314265.us-east1.run.app"

# Ejemplo: age_experience = 1.5
r = requests.post(f"{BASE}/api/2", timeout=15)

r.raise_for_status()
print(r.json())
# Out:
# {'Salary ': 4276731}

# %%
r = requests.post(f"{BASE}/api/", json={"age_experience": 1.5}, timeout=15)
print(f"Estatus code: {r.status_code} y json de respuesta {r.json()}")
# Out:
# Estatus code: 200 y json de respuesta {'Salary ': 3556500}
